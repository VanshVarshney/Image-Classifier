# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

from collections import OrderedDict
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

from torch.autograd import Variable

from PIL import Image
import torchvision
import matplotlib.pyplot as plt
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader
import shutil

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
local_machine = False

# %%
data_dir = '/Users/wittmann/projects/aipnd-project/flower_data' if local_machine else '/input'
train_dir = data_dir + '/train/'
valid_dir = data_dir + '/valid/'
test_dir = data_dir + '/test/'
my_data = data_dir + '/my_data/'

# %%
# TODO: Define your transforms for the training, validation, and testing set
train_transforms = transforms.Compose([
    transforms.RandomRotation(30),
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], 
                         [0.229, 0.224, 0.225])
])

# TODO: Load the datasets with ImageFolder
train_dataset = datasets.ImageFolder(train_dir, transform=train_transforms)

# TODO: Using the image datasets and the trainforms, define the dataloaders
trainloader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# %%
# Test and validation sets
test_transforms = transforms.Compose([
#    transforms.RandomRotation(30),
#    transforms.RandomResizedCrop(224),
#    transforms.RandomHorizontalFlip(),
    transforms.Resize(255),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], 
                         [0.229, 0.224, 0.225])
])

# TODO: Load the datasets with ImageFolder
valid_dataset = datasets.ImageFolder(valid_dir, transform=test_transforms)
test_dataset = datasets.ImageFolder(test_dir, transform=test_transforms)

# TODO: Using the image datasets and the trainforms, define the dataloaders
validloader = DataLoader(valid_dataset, batch_size=32, shuffle=False)
testloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %%
# Test the loaders

images, labels = next(iter(trainloader))
imshow(images[2])

images, labels = next(iter(validloader))
imshow(images[2])

images, labels = next(iter(testloader))
imshow(images[2])

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. If you want to talk through it with someone, chat with your fellow students! You can also ask questions on the forums or join the instructors in office hours.
#
# Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.

# %%
# TODO: Build and train your network
model = models.densenet121(pretrained=True)
# Out:
# /usr/local/lib/python3.6/site-packages/torchvision/models/densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)

# %%
# Freeze the feature parameters
for params in model.parameters():
    params.requires_grad = False

# %%
classifier = nn.Sequential(OrderedDict([
    ('fc1', nn.Linear(1024, 200)),
    ('relu', nn.ReLU()), 
    ('fc2', nn.Linear(200, 102)),
    ('drop', nn.Dropout(p=0.5)),
    ('output', nn.LogSoftmax(dim=1))
]))

# %%
model.classifier = classifier

# %%
def save_checkpoint(state, is_best=False, filename='checkpoint.pth.tar'):
    torch.save(state, filename)
    if is_best:
        shutil.copyfile(filename, 'model_best.pth.tar')

# %%
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)

cuda = torch.cuda.is_available()

if cuda:
    model.cuda()
else:
    model.cpu()
    
epochs = 3
print_every = 5
save_every = 50
steps = 0

for e in range(epochs):
    model.train()
    running_loss = 0
    accuracy_train = 0
    
    for images, labels in iter(trainloader):
        steps += 1
        
        inputs, labels = Variable(images), Variable(labels)
        
        optimizer.zero_grad()
        
        if cuda:
            inputs, labels = inputs.cuda(), labels.cuda()
        
        output = model.forward(inputs)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        ps_train = torch.exp(output).data
        equality_train = (labels.data == ps_train.max(1)[1])
        accuracy_train += equality_train.type_as(torch.FloatTensor()).mean()
        
        
        
        if steps % print_every == 0:
            model.eval()
            
            accuracy = 0
            valid_loss = 0
            
            for images, labels in validloader:
                with torch.no_grad():
                    inputs = Variable(images)
                    labels = Variable(labels)

                    if cuda:
                        inputs, labels = inputs.cuda(), labels.cuda()

                    output = model.forward(inputs)

                    valid_loss += criterion(output, labels).item()

                    ps = torch.exp(output).data
                    equality = (labels.data == ps.max(1)[1])

                    accuracy += equality.type_as(torch.FloatTensor()).mean()
                
            print("Epoch: {}/{}.. ".format(e+1, epochs), 
                  "Training Loss: {:.3f}.. ".format(running_loss/print_every),
                  "Validation Loss: {:.3f}..".format(valid_loss/len(validloader)),
                  "Training Accuracy: {:.3f}".format(accuracy_train/len(trainloader)),
                  "Validation Accuracy: {:.3f}".format(accuracy/len(validloader)))
            
            running_loss = 0
            model.train()
            
        if steps % save_every == 0:
            print("Saving step number {}...".format(steps))
            state = {'state_dict': model.classifier.state_dict(),
                     'optimizer' : optimizer.state_dict(),
                     'class_to_idx':train_dataset.class_to_idx}
            
            save_checkpoint(state)
            print("Done!")
# Out:
# Epoch: 1/3..  Training Loss: 4.679..  Validation Loss: 4.591.. Training Accuracy: 0.000 Validation Accuracy: 0.050
# Epoch: 1/3..  Training Loss: 4.740..  Validation Loss: 4.550.. Training Accuracy: 0.001 Validation Accuracy: 0.056
# Epoch: 1/3..  Training Loss: 4.568..  Validation Loss: 4.529.. Training Accuracy: 0.002 Validation Accuracy: 0.059
# Epoch: 1/3..  Training Loss: 4.581..  Validation Loss: 4.504.. Training Accuracy: 0.004 Validation Accuracy: 0.054
# Epoch: 1/3..  Training Loss: 4.465..  Validation Loss: 4.467.. Training Accuracy: 0.006 Validation Accuracy: 0.055
# Epoch: 1/3..  Training Loss: 4.457..  Validation Loss: 4.417.. Training Accuracy: 0.008 Validation Accuracy: 0.088
# Epoch: 1/3..  Training Loss: 4.372..  Validation Loss: 4.363.. Training Accuracy: 0.009 Validation Accuracy: 0.066
# Epoch: 1/3..  Training Loss: 4.337..  Validation Loss: 4.304.. Training Accuracy: 0.012 Validation Accuracy: 0.094
# Epoch: 1/3..  Training Loss: 4.401..  Validation Loss: 4.270.. Training Accuracy: 0.014 Validation Accuracy: 0.123
# Epoch: 1/3..  Training Loss: 4.434..  Validation Loss: 4.262.. Training Accuracy: 0.015 Validation Accuracy: 0.133
# Saving step number 50...
# Done!
# Epoch: 1/3..  Training Loss: 4.439..  Validation Loss: 4.266.. Training Accuracy: 0.016 Validation Accuracy: 0.173
# Epoch: 1/3..  Training Loss: 4.453..  Validation Loss: 4.241.. Training Accuracy: 0.018 Validation Accuracy: 0.200
# Epoch: 1/3..  Training Loss: 4.371..  Validation Loss: 4.232.. Training Accuracy: 0.021 Validation Accuracy: 0.208
# Epoch: 1/3..  Training Loss: 4.219..  Validation Loss: 4.154.. Training Accuracy: 0.025 Validation Accuracy: 0.184
# Epoch: 1/3..  Training Loss: 4.299..  Validation Loss: 4.085.. Training Accuracy: 0.027 Validation Accuracy: 0.190
# Epoch: 1/3..  Training Loss: 4.343..  Validation Loss: 4.036.. Training Accuracy: 0.029 Validation Accuracy: 0.206
# Epoch: 1/3..  Training Loss: 4.214..  Validation Loss: 4.006.. Training Accuracy: 0.033 Validation Accuracy: 0.241
# Epoch: 1/3..  Training Loss: 4.164..  Validation Loss: 3.968.. Training Accuracy: 0.037 Validation Accuracy: 0.190
# Epoch: 1/3..  Training Loss: 4.225..  Validation Loss: 3.916.. Training Accuracy: 0.039 Validation Accuracy: 0.233
# Epoch: 1/3..  Training Loss: 4.062..  Validation Loss: 3.859.. Training Accuracy: 0.044 Validation Accuracy: 0.267
# Saving step number 100...
# Done!
# Epoch: 1/3..  Training Loss: 4.128..  Validation Loss: 3.806.. Training Accuracy: 0.048 Validation Accuracy: 0.258
# Epoch: 1/3..  Training Loss: 4.052..  Validation Loss: 3.753.. Training Accuracy: 0.052 Validation Accuracy: 0.298
# Epoch: 1/3..  Training Loss: 3.921..  Validation Loss: 3.729.. Training Accuracy: 0.057 Validation Accuracy: 0.301
# Epoch: 1/3..  Training Loss: 4.094..  Validation Loss: 3.673.. Training Accuracy: 0.061 Validation Accuracy: 0.309
# Epoch: 1/3..  Training Loss: 3.976..  Validation Loss: 3.614.. Training Accuracy: 0.065 Validation Accuracy: 0.319
# Epoch: 1/3..  Training Loss: 3.954..  Validation Loss: 3.578.. Training Accuracy: 0.068 Validation Accuracy: 0.304
# Epoch: 1/3..  Training Loss: 4.003..  Validation Loss: 3.510.. Training Accuracy: 0.073 Validation Accuracy: 0.356
# Epoch: 1/3..  Training Loss: 3.970..  Validation Loss: 3.453.. Training Accuracy: 0.077 Validation Accuracy: 0.411
# Epoch: 1/3..  Training Loss: 4.098..  Validation Loss: 3.451.. Training Accuracy: 0.080 Validation Accuracy: 0.419
# Epoch: 1/3..  Training Loss: 3.994..  Validation Loss: 3.464.. Training Accuracy: 0.084 Validation Accuracy: 0.443
# Saving step number 150...
# Done!
# Epoch: 1/3..  Training Loss: 3.701..  Validation Loss: 3.400.. Training Accuracy: 0.090 Validation Accuracy: 0.440
# Epoch: 1/3..  Training Loss: 3.727..  Validation Loss: 3.344.. Training Accuracy: 0.096 Validation Accuracy: 0.381
# Epoch: 1/3..  Training Loss: 3.596..  Validation Loss: 3.268.. Training Accuracy: 0.102 Validation Accuracy: 0.384
# Epoch: 1/3..  Training Loss: 3.552..  Validation Loss: 3.226.. Training Accuracy: 0.109 Validation Accuracy: 0.428
# Epoch: 1/3..  Training Loss: 3.448..  Validation Loss: 3.144.. Training Accuracy: 0.116 Validation Accuracy: 0.464
# Epoch: 1/3..  Training Loss: 3.721..  Validation Loss: 3.078.. Training Accuracy: 0.121 Validation Accuracy: 0.490
# Epoch: 1/3..  Training Loss: 3.765..  Validation Loss: 3.033.. Training Accuracy: 0.126 Validation Accuracy: 0.490
# Epoch: 1/3..  Training Loss: 3.723..  Validation Loss: 2.957.. Training Accuracy: 0.131 Validation Accuracy: 0.510
# Epoch: 1/3..  Training Loss: 3.773..  Validation Loss: 2.931.. Training Accuracy: 0.136 Validation Accuracy: 0.502
# Epoch: 1/3..  Training Loss: 3.610..  Validation Loss: 2.887.. Training Accuracy: 0.142 Validation Accuracy: 0.563
# Saving step number 200...
# Done!
# Epoch: 1/3..  Training Loss: 3.656..  Validation Loss: 2.825.. Training Accuracy: 0.149 Validation Accuracy: 0.569
# Epoch: 2/3..  Training Loss: 3.482..  Validation Loss: 2.806.. Training Accuracy: 0.007 Validation Accuracy: 0.543
# Epoch: 2/3..  Training Loss: 3.345..  Validation Loss: 2.760.. Training Accuracy: 0.014 Validation Accuracy: 0.584
# Epoch: 2/3..  Training Loss: 3.260..  Validation Loss: 2.748.. Training Accuracy: 0.023 Validation Accuracy: 0.585
# Epoch: 2/3..  Training Loss: 3.531..  Validation Loss: 2.710.. Training Accuracy: 0.030 Validation Accuracy: 0.584
# Epoch: 2/3..  Training Loss: 3.560..  Validation Loss: 2.661.. Training Accuracy: 0.036 Validation Accuracy: 0.584
# Epoch: 2/3..  Training Loss: 3.148..  Validation Loss: 2.602.. Training Accuracy: 0.044 Validation Accuracy: 0.596
# Epoch: 2/3..  Training Loss: 3.232..  Validation Loss: 2.576.. Training Accuracy: 0.054 Validation Accuracy: 0.591
# Epoch: 2/3..  Training Loss: 3.512..  Validation Loss: 2.553.. Training Accuracy: 0.059 Validation Accuracy: 0.584
# Epoch: 2/3..  Training Loss: 3.595..  Validation Loss: 2.528.. Training Accuracy: 0.065 Validation Accuracy: 0.608
# Saving step number 250...
# Done!
# Epoch: 2/3..  Training Loss: 3.400..  Validation Loss: 2.524.. Training Accuracy: 0.073 Validation Accuracy: 0.631
# Epoch: 2/3..  Training Loss: 3.014..  Validation Loss: 2.504.. Training Accuracy: 0.082 Validation Accuracy: 0.610
# Epoch: 2/3..  Training Loss: 3.476..  Validation Loss: 2.422.. Training Accuracy: 0.089 Validation Accuracy: 0.651
# Epoch: 2/3..  Training Loss: 3.374..  Validation Loss: 2.376.. Training Accuracy: 0.096 Validation Accuracy: 0.655
# Epoch: 2/3..  Training Loss: 3.180..  Validation Loss: 2.347.. Training Accuracy: 0.104 Validation Accuracy: 0.627
# Epoch: 2/3..  Training Loss: 3.284..  Validation Loss: 2.350.. Training Accuracy: 0.111 Validation Accuracy: 0.626
# Epoch: 2/3..  Training Loss: 3.460..  Validation Loss: 2.324.. Training Accuracy: 0.118 Validation Accuracy: 0.652
# Epoch: 2/3..  Training Loss: 3.145..  Validation Loss: 2.372.. Training Accuracy: 0.127 Validation Accuracy: 0.632
# Epoch: 2/3..  Training Loss: 3.295..  Validation Loss: 2.320.. Training Accuracy: 0.134 Validation Accuracy: 0.656
# Epoch: 2/3..  Training Loss: 3.202..  Validation Loss: 2.306.. Training Accuracy: 0.142 Validation Accuracy: 0.650
# Saving step number 300...
# Done!
# Epoch: 2/3..  Training Loss: 3.032..  Validation Loss: 2.261.. Training Accuracy: 0.152 Validation Accuracy: 0.677
# Epoch: 2/3..  Training Loss: 3.404..  Validation Loss: 2.211.. Training Accuracy: 0.159 Validation Accuracy: 0.685
# Epoch: 2/3..  Training Loss: 3.037..  Validation Loss: 2.206.. Training Accuracy: 0.169 Validation Accuracy: 0.701
# Epoch: 2/3..  Training Loss: 3.181..  Validation Loss: 2.166.. Training Accuracy: 0.177 Validation Accuracy: 0.728
# Epoch: 2/3..  Training Loss: 3.145..  Validation Loss: 2.136.. Training Accuracy: 0.186 Validation Accuracy: 0.713
# Epoch: 2/3..  Training Loss: 3.135..  Validation Loss: 2.102.. Training Accuracy: 0.193 Validation Accuracy: 0.720
# Epoch: 2/3..  Training Loss: 3.278..  Validation Loss: 2.084.. Training Accuracy: 0.201 Validation Accuracy: 0.700
# Epoch: 2/3..  Training Loss: 3.069..  Validation Loss: 2.071.. Training Accuracy: 0.209 Validation Accuracy: 0.696
# Epoch: 2/3..  Training Loss: 3.226..  Validation Loss: 2.049.. Training Accuracy: 0.217 Validation Accuracy: 0.698
# Epoch: 2/3..  Training Loss: 3.120..  Validation Loss: 1.984.. Training Accuracy: 0.225 Validation Accuracy: 0.714
# Saving step number 350...
# Done!
# Epoch: 2/3..  Training Loss: 3.080..  Validation Loss: 2.016.. Training Accuracy: 0.234 Validation Accuracy: 0.697
# Epoch: 2/3..  Training Loss: 3.205..  Validation Loss: 1.980.. Training Accuracy: 0.242 Validation Accuracy: 0.715
# Epoch: 2/3..  Training Loss: 2.877..  Validation Loss: 1.970.. Training Accuracy: 0.252 Validation Accuracy: 0.714
# Epoch: 2/3..  Training Loss: 2.956..  Validation Loss: 1.995.. Training Accuracy: 0.261 Validation Accuracy: 0.701
# Epoch: 2/3..  Training Loss: 3.118..  Validation Loss: 1.953.. Training Accuracy: 0.269 Validation Accuracy: 0.727
# Epoch: 2/3..  Training Loss: 3.011..  Validation Loss: 1.932.. Training Accuracy: 0.278 Validation Accuracy: 0.738
# Epoch: 2/3..  Training Loss: 3.085..  Validation Loss: 1.903.. Training Accuracy: 0.286 Validation Accuracy: 0.755
# Epoch: 2/3..  Training Loss: 3.218..  Validation Loss: 1.888.. Training Accuracy: 0.293 Validation Accuracy: 0.741
# Epoch: 2/3..  Training Loss: 2.763..  Validation Loss: 1.857.. Training Accuracy: 0.303 Validation Accuracy: 0.777
# Epoch: 2/3..  Training Loss: 2.841..  Validation Loss: 1.864.. Training Accuracy: 0.314 Validation Accuracy: 0.782
# Saving step number 400...
# Done!
# Epoch: 2/3..  Training Loss: 3.098..  Validation Loss: 1.821.. Training Accuracy: 0.323 Validation Accuracy: 0.781
# Epoch: 2/3..  Training Loss: 2.838..  Validation Loss: 1.782.. Training Accuracy: 0.332 Validation Accuracy: 0.787
# Epoch: 3/3..  Training Loss: 2.966..  Validation Loss: 1.776.. Training Accuracy: 0.009 Validation Accuracy: 0.800
# Epoch: 3/3..  Training Loss: 2.834..  Validation Loss: 1.754.. Training Accuracy: 0.020 Validation Accuracy: 0.795
# Epoch: 3/3..  Training Loss: 2.834..  Validation Loss: 1.739.. Training Accuracy: 0.029 Validation Accuracy: 0.784
# Epoch: 3/3..  Training Loss: 2.988..  Validation Loss: 1.739.. Training Accuracy: 0.038 Validation Accuracy: 0.788
# Epoch: 3/3..  Training Loss: 2.767..  Validation Loss: 1.729.. Training Accuracy: 0.049 Validation Accuracy: 0.754
# Epoch: 3/3..  Training Loss: 2.951..  Validation Loss: 1.708.. Training Accuracy: 0.058 Validation Accuracy: 0.732
# Epoch: 3/3..  Training Loss: 3.200..  Validation Loss: 1.684.. Training Accuracy: 0.066 Validation Accuracy: 0.753
# Epoch: 3/3..  Training Loss: 3.223..  Validation Loss: 1.674.. Training Accuracy: 0.074 Validation Accuracy: 0.762
# Saving step number 450...
# Done!
# Epoch: 3/3..  Training Loss: 2.974..  Validation Loss: 1.670.. Training Accuracy: 0.083 Validation Accuracy: 0.777
# Epoch: 3/3..  Training Loss: 2.826..  Validation Loss: 1.692.. Training Accuracy: 0.093 Validation Accuracy: 0.758
# Epoch: 3/3..  Training Loss: 2.682..  Validation Loss: 1.682.. Training Accuracy: 0.103 Validation Accuracy: 0.785
# Epoch: 3/3..  Training Loss: 2.976..  Validation Loss: 1.668.. Training Accuracy: 0.112 Validation Accuracy: 0.779
# Epoch: 3/3..  Training Loss: 3.056..  Validation Loss: 1.687.. Training Accuracy: 0.121 Validation Accuracy: 0.743
# Epoch: 3/3..  Training Loss: 2.992..  Validation Loss: 1.661.. Training Accuracy: 0.129 Validation Accuracy: 0.784
# Epoch: 3/3..  Training Loss: 2.926..  Validation Loss: 1.655.. Training Accuracy: 0.139 Validation Accuracy: 0.813
# Epoch: 3/3..  Training Loss: 2.722..  Validation Loss: 1.636.. Training Accuracy: 0.150 Validation Accuracy: 0.778
# Epoch: 3/3..  Training Loss: 3.011..  Validation Loss: 1.624.. Training Accuracy: 0.158 Validation Accuracy: 0.801
# Epoch: 3/3..  Training Loss: 2.836..  Validation Loss: 1.584.. Training Accuracy: 0.168 Validation Accuracy: 0.807
# Saving step number 500...
# Done!
# Epoch: 3/3..  Training Loss: 2.793..  Validation Loss: 1.576.. Training Accuracy: 0.177 Validation Accuracy: 0.811
# Epoch: 3/3..  Training Loss: 2.919..  Validation Loss: 1.562.. Training Accuracy: 0.187 Validation Accuracy: 0.787
# Epoch: 3/3..  Training Loss: 2.777..  Validation Loss: 1.550.. Training Accuracy: 0.197 Validation Accuracy: 0.787
# Epoch: 3/3..  Training Loss: 2.955..  Validation Loss: 1.543.. Training Accuracy: 0.206 Validation Accuracy: 0.807
# Epoch: 3/3..  Training Loss: 3.018..  Validation Loss: 1.554.. Training Accuracy: 0.214 Validation Accuracy: 0.808
# Epoch: 3/3..  Training Loss: 3.037..  Validation Loss: 1.516.. Training Accuracy: 0.223 Validation Accuracy: 0.794
# Epoch: 3/3..  Training Loss: 2.639..  Validation Loss: 1.529.. Training Accuracy: 0.234 Validation Accuracy: 0.799
# Epoch: 3/3..  Training Loss: 2.887..  Validation Loss: 1.578.. Training Accuracy: 0.243 Validation Accuracy: 0.770
# Epoch: 3/3..  Training Loss: 3.009..  Validation Loss: 1.552.. Training Accuracy: 0.252 Validation Accuracy: 0.814
# Epoch: 3/3..  Training Loss: 2.989..  Validation Loss: 1.548.. Training Accuracy: 0.261 Validation Accuracy: 0.834
# Saving step number 550...
# Done!
# Epoch: 3/3..  Training Loss: 2.852..  Validation Loss: 1.507.. Training Accuracy: 0.271 Validation Accuracy: 0.849
# Epoch: 3/3..  Training Loss: 2.941..  Validation Loss: 1.496.. Training Accuracy: 0.280 Validation Accuracy: 0.817
# Epoch: 3/3..  Training Loss: 2.645..  Validation Loss: 1.484.. Training Accuracy: 0.291 Validation Accuracy: 0.805
# Epoch: 3/3..  Training Loss: 2.775..  Validation Loss: 1.492.. Training Accuracy: 0.300 Validation Accuracy: 0.795
# Epoch: 3/3..  Training Loss: 2.871..  Validation Loss: 1.474.. Training Accuracy: 0.309 Validation Accuracy: 0.790
# Epoch: 3/3..  Training Loss: 2.656..  Validation Loss: 1.468.. Training Accuracy: 0.320 Validation Accuracy: 0.809
# Epoch: 3/3..  Training Loss: 2.673..  Validation Loss: 1.470.. Training Accuracy: 0.330 Validation Accuracy: 0.814
# Epoch: 3/3..  Training Loss: 2.809..  Validation Loss: 1.451.. Training Accuracy: 0.341 Validation Accuracy: 0.815
# Epoch: 3/3..  Training Loss: 2.712..  Validation Loss: 1.436.. Training Accuracy: 0.351 Validation Accuracy: 0.831
# Epoch: 3/3..  Training Loss: 2.682..  Validation Loss: 1.429.. Training Accuracy: 0.361 Validation Accuracy: 0.836
# Saving step number 600...
# Done!
# Epoch: 3/3..  Training Loss: 2.806..  Validation Loss: 1.441.. Training Accuracy: 0.371 Validation Accuracy: 0.837
# Epoch: 3/3..  Training Loss: 2.947..  Validation Loss: 1.397.. Training Accuracy: 0.379 Validation Accuracy: 0.819
# Epoch: 3/3..  Training Loss: 2.796..  Validation Loss: 1.369.. Training Accuracy: 0.389 Validation Accuracy: 0.838

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
cuda = True

# %%
# TODO: Do validation on the test set

model.eval()
criterion = nn.NLLLoss()


if cuda:
    model.cuda()
else:
    model.cpu()
    
accuracy = 0
test_loss = 0

for images, labels in testloader:
    with torch.no_grad():
        inputs = Variable(images)
        labels = Variable(labels)

        if cuda:
            inputs, labels = inputs.cuda(), labels.cuda()

        output = model.forward(inputs)

        test_loss += criterion(output, labels).item()

        ps = torch.exp(output).data
        equality = (labels.data == ps.max(1)[1])

        accuracy += equality.type_as(torch.FloatTensor()).mean()

print("Test Loss: {:.3f}..".format(test_loss/len(testloader)),
      "Test Accuracy: {:.3f}".format(accuracy/len(testloader)))
# Out:
# Test Loss: 1.415.. Test Accuracy: 0.815

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
class_to_idx = train_dataset.class_to_idx
model.class_to_idx = class_to_idx
model.idx_to_class = inv_map = {v: k for k, v in class_to_idx.items()}

# %%
def save_checkpoint(state, is_best=False, filename='checkpoint.pth.tar'):
    torch.save(state, filename)
    if is_best:
        shutil.copyfile(filename, 'model_best.pth.tar')

# %%
# TODO: Save the checkpoint 
state = {#'input_size': 784,
         'output_size': 102,
         'state_dict': model.classifier.state_dict(),
         'optimizer' : optimizer.state_dict(),
         'class_to_idx':train_dataset.class_to_idx
}

# %%
save_checkpoint(state)

# %%
ls
# Out:
# Image Classifier Project - old.ipynb  assets/             predict.py
# Image Classifier Project.ipynb        cat_to_name.json    train.py
# LICENSE                               checkpoint.pth.tar
# README.md                             model_best.pth.tar

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
def load_checkpoint(filepath):
    if local_machine:
        checkpoint = torch.load(filepath, map_location='cpu')
    else:
        checkpoint = torch.load(filepath)
    model = models.densenet121(pretrained=True)
    
    # Freeze the feature parameters
    for params in model.parameters():
        params.requires_grad = False
    
    classifier = nn.Sequential(OrderedDict([
        ('fc1', nn.Linear(1024, 200)),
        ('relu', nn.ReLU()), 
        ('fc2', nn.Linear(200, 102)),
        ('drop', nn.Dropout(p=0.5)),
        ('output', nn.LogSoftmax(dim=1))
    ]))

    classifier.load_state_dict(checkpoint['state_dict'])
    
    
    model.classifier = classifier
    class_to_idx = checkpoint['class_to_idx']
    model.class_to_idx = class_to_idx
    model.idx_to_class = inv_map = {v: k for k, v in class_to_idx.items()}
    
    return model

# %%
model = load_checkpoint("checkpoint.pth.tar")
# Out:
# /usr/local/lib/python3.6/site-packages/torchvision/models/densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    
    # TODO: Process a PIL image for use in a PyTorch model
    img_transforms = transforms.Compose([
            transforms.Resize(255),
            transforms.CenterCrop(224),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], 
                         [0.229, 0.224, 0.225])
        ])
    
    image = img_transforms(Image.open(image))
    
    return image

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %%
img = process_image(test_dir+'1/image_06743.jpg')
imshow(img)

# %%
path = test_dir+'2/image_05100.jpg'
imshow(process_image(path))

# %%
path = my_data+'4.jpeg'
imshow(process_image(path))

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
path = test_dir+'2/image_05100.jpg'

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    
    # TODO: Implement the code to predict the class from an image file
    image_data = process_image(image_path)
    if cuda:
        model.cuda()
    else:
        model.cpu()
        
    model_p = model.eval()
    
    inputs = Variable(image_data.unsqueeze(0))
    #labels = Variable(labels)

    if cuda:
        inputs = inputs.cuda()#, labels.cuda()
    
    output = model_p(inputs)
    ps = torch.exp(output).data
    
    ps_top = ps.topk(topk)
    idx2class = model.idx_to_class
    probs = ps_top[0].tolist()[0]
    classes = [idx2class[i] for i in ps_top[1].tolist()[0]]
    
    return probs, classes

# %%
probs, classes = predict(path, model)

print(probs)
print(classes)
# Out:
# [0.4716368615627289, 0.04464380070567131, 0.027453023940324783, 0.025480281561613083, 0.025227971374988556]
# ['2', '40', '97', '77', '89']

# %%
path = test_dir+'1/image_06743.jpg'

probs, classes = predict(path, model)

print(probs)
print(classes)
# Out:
# [0.15436767041683197, 0.08192838728427887, 0.06910596787929535, 0.054779160767793655, 0.05134551227092743]
# ['1', '51', '76', '86', '12']

# %%
path = train_dir+'1/image_06734.jpg'
probs, classes = predict(path, model)

print(probs)
print(classes)
# Out:
# [0.08672624081373215, 0.08468269556760788, 0.07856173813343048, 0.06811103969812393, 0.05102117732167244]
# ['51', '55', '1', '95', '76']

# %%
def predict_from_checkpoint(image_path, model_checkpoint_path, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    
    # TODO: Implement the code to predict the class from an image file
    model = load_checkpoint(model_checkpoint_path)
    image_data = process_image(image_path)
    model_p = model.eval()
    output = model_p(image_data.unsqueeze(0))
    ps = torch.exp(output).data
    ps_top = ps.topk(topk)
    idx2class = model.idx_to_class
    probs = ps_top[0].tolist()[0]
    classes = [idx2class[i] for i in ps_top[1].tolist()[0]]
    
    return probs, classes

# %%
path = test_dir+'2/image_05100.jpg'
predict_from_checkpoint(path, 'model_best.pth.tar')
# Out:
# /Users/wittmann/anaconda/envs/py36/lib/python3.6/site-packages/torchvision-0.2.1-py3.6.egg/torchvision/models/densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# ([0.07331303507089615,
#   0.06454355269670486,
#   0.044784706085920334,
#   0.04357432574033737,
#   0.03594498708844185],
#  ['86', '62', '18', '2', '46'])

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
path = test_dir+'2/image_05100.jpg'

# %%
def plot_probas(path, model, cat_to_name):
    fig, (ax1, ax2) = plt.subplots(figsize=(6,7), nrows=2)
    ax1.axis('off')
    probs, classes = predict(path, model)
    class_names = [cat_to_name[i] for i in classes]
    ax2.barh(class_names, probs)
    imshow(process_image(path), ax=ax1)

# %%
plot_probas(path, model, cat_to_name)
